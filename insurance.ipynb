# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------------------- -------- 6.3/8.1 MB 32.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 30.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 33.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ----------------------- ---------------- 7.6/12.8 MB 37.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 35.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------- ----------- 7.9/11.0 MB 38.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 34.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------  6.8/7.0 MB 38.4 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
np.__version__, pd.__version__, sns.__version__, matplotlib.__version__
# Out:
# ('2.3.2', '2.3.2', '0.13.2', '3.10.5')

# %%
df=pd.read_csv("D:\Machine Learning\Dataset\insurance.csv")

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region         fees
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children          fees
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.rename(columns = {"charges":"fees"}, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'fees'], dtype='object')

# %%
sns.countplot(data=df, x="smoker")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=df, x="region")
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.displot(data=df, x="fees")

# %%
sns.displot(x=df['age'])

# %%
sns.boxplot(x=df["smoker"], y=df["fees"])
# Out:
# <Axes: xlabel='smoker', ylabel='fees'>

# %%
sns.scatterplot(x=df["age"], y=df["fees"], hue=df["bmi"])
# Out:
# <Axes: xlabel='age', ylabel='fees'>

# %%
sns.scatterplot(x=df["age"], y=df["fees"], hue=df["region"])
# Out:
# <Axes: xlabel='age', ylabel='fees'>

# %%
sns.scatterplot(x=df["age"], y=df["fees"], hue=df["sex"])
# Out:
# <Axes: xlabel='age', ylabel='fees'>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'fees'], dtype='object')

# %%
df = df.drop('sex', axis="columns")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df = df.drop('sex', axis="columns")
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
df.columns
# Out:
# Index(['age', 'bmi', 'children', 'smoker', 'region', 'fees'], dtype='object')

# %%
df.head()
# Out:
#    age     bmi  children smoker     region         fees
# 0   19  27.900         0    yes  southwest  16884.92400
# 1   18  33.770         1     no  southeast   1725.55230
# 2   28  33.000         3     no  southeast   4449.46200
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520

# %%
df=df.drop(0, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df=df.drop(0, axis=0)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
# ...

# %%
df.head()
# Out:
#    age     bmi  children smoker     region         fees
# 1   18  33.770         1     no  southeast   1725.55230
# 2   28  33.000         3     no  southeast   4449.46200
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520
# 5   31  25.740         0     no  southeast   3756.62160

# %%
df=df.drop(2,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df=df.drop(2,axis=0)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
# ...

# %%
df.head()
# Out:
#    age     bmi  children smoker     region         fees
# 1   18  33.770         1     no  southeast   1725.55230
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520
# 5   31  25.740         0     no  southeast   3756.62160
# 6   46  33.440         1     no  southeast   8240.58960

# %%
df.columns
# Out:
# Index(['age', 'bmi', 'children', 'smoker', 'region', 'fees'], dtype='object')

# %%
pip install scikit-learn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ------------------ --------------------- 3.9/8.7 MB 24.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 28.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ------- -------------------------------- 7.1/38.5 MB 35.5 MB/s eta 0:00:01
#    ------------- -------------------------- 12.8/38.5 MB 34.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 21.8/38.5 MB 34.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.3/38.5 MB 34.2 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.5 MB 33.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 31.3 MB/s  0:00:01
# ...
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
# ...

# %%
uv add scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\python.exe: No module named uv

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#    age     bmi  children smoker     region         fees
# 1   18  33.770         1     no  southeast   1725.55230
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520
# 5   31  25.740         0     no  southeast   3756.62160
# 6   46  33.440         1     no  southeast   8240.58960

# %%
le=LabelEncoder()
df['smoker']= le.fit_transform(df["smoker"])

# %%
le.classes_
# Out:
# array([0, 1])

# %%
df.head()
# Out:
#    age     bmi  children  smoker     region         fees
# 1   18  33.770         1       0  southeast   1725.55230
# 3   33  22.705         0       0  northwest  21984.47061
# 4   32  28.880         0       0  northwest   3866.85520
# 5   31  25.740         0       0  southeast   3756.62160
# 6   46  33.440         1       0  southeast   8240.58960

# %%
df['region'] = le.fit_transform(df['region'])
df['region'].unique()
# Out:
# array([2, 1, 0, 3])

# %%
le.classes_
# Out:
# array([0, 1, 2, 3])

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
